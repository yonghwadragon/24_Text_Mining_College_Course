# %% [markdown]
# 쿼리?로 코드 깔끔하게 \
# okt 7줄 외워버리기

# %% [markdown]
# 데이터는 많고 이것 저것 해보면 실력이 늘어요

# %% [markdown]
# 아래 외워보기 한번 해보기

# %% [markdown]
# 1. train_df.csv 읽고 ...
# 2. 발화자는 c인 것만 남겨놓으세요
# 3. 인텐트 각 범주별 카운트를 하세요
# 4. 빈도가 높은 두 범주만 남겨놓으세요
# 5. 분류하세요 \
# 나중에 파티닝으랑 잘 되는 지 확인

# %%
import pandas as pd
data = pd.read_csv("train_df.csv", encoding="CP949")
data.head()
# Out:
#      IDX 발화자                                                발화문  \
# 0  28414   c                     혹시 플라워 스마트 톡 케이스 블루로 바꿀 수 있나요?
# 1  28415   s                               현재 배송 중으로 교환이 어렵습니다.
# 2  28416   c  USB1.0 속도 밖에 나오질 않네요리더 기만 교환 바랍니다. 불량 리더기도 택배로...
# 3  28417   s                           네.리더기만 불량이 여교환 문의해주셨는데요.
# 4  28418   c        빨리 챙겨서 보내주시기 바랍니다 아니면 다시 1개는 교환으로 보내야 하는지요?
#
#               인텐트    상담번호  상담내순번
# 0  교환|반품|환불_일반_요청  389321      1
# 1  교환|반품|환불_일반_요청  389321      2
# 2  교환|반품|환불_일반_요청  179614      1
# 3  교환|반품|환불_일반_요청  179614      2
# 4  교환|반품|환불_일반_요청  325053      1

# %%
data_c=data[data.발화자=='c']
data_c
# Out:
#           IDX 발화자                                                발화문  \
# 0       28414   c                     혹시 플라워 스마트 톡 케이스 블루로 바꿀 수 있나요?
# 2       28416   c  USB1.0 속도 밖에 나오질 않네요리더 기만 교환 바랍니다. 불량 리더기도 택배로...
# 4       28418   c        빨리 챙겨서 보내주시기 바랍니다 아니면 다시 1개는 교환으로 보내야 하는지요?
# 6       28420   c            불량인 거 같아 요택배박스는 버렸거든요 이 거반품해야 될 거 같은데요?
# 8       28422   c  배송 방금 받았는데 반품한 물건 보내셨나 봐요테 잎이 뜯어져 있고 사용설명서도 없어...
# ...       ...  ..                                                ...
# 29350  742986   c  오늘 받았는데요소 건스트림쿨 제품 맞교환 신청했는데 교환받은 건 소다스테이션인데 이...
# 29352  742988   c                                   HDMI선은 언제 출고되나요?
# 29354  742990   c      분명 지난주에 반품 배송 완료된 걸로 조회되는데 왜 처리 진행이 안 되는 건가요?
# 29356  742992   c                         실린더 맞교환과 내츄럴 맞교환에 차이가 뭔가요?
# 29358  742994   c  그쪽에서 물건을 잘못 보냈으면 확인을 하고 물품을 교환하던지 차액을 돌려주든지 고객...
#
#                   인텐트    상담번호  상담내순번
# 0      교환|반품|환불_일반_요청  389321      1
# 2      교환|반품|환불_일반_요청  179614      1
# ...

# %%
data_c.인텐트.value_counts()
# Out:
# 인텐트
# 교환|반품|환불_일반_질문    4769
# 교환|반품|환불_시간_질문    4226
# 교환|반품|환불_방법_질문    3934
# 교환|반품|환불_비용_질문    1964
# 교환|반품|환불_방법_요청    1443
# 교환|반품|환불_시간_요청     272
# 교환|반품|환불_일반_요청     188
# 교환|반품|환불_일반_확인     103
# 교환|반품|환불_방법_확인      74
# 교환|반품|환불_비용_요청      67
# 교환|반품|환불_시간_확인      38
# 교환|반품|환불_비용_확인      32
# 교환|반품|환불_방법_비교       5
# 교환|반품|환불_일반_비교       3
# 교환|반품|환불_시간_비교       1
# 교환|반품|환불_비용_비교       1
# Name: count, dtype: int64

# %%
data2=data_c [ (data_c.인텐트 == '교환|반품|환불_일반_질문') | ('교환|반품|환불_시간_질문') ]
data2.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     310         #  (xint or xbool) and (yint or bool)
# --> 311         result = op(x, y)
#     312     except TypeError:
#
# TypeError: ufunc 'bitwise_or' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     324             try:
# --> 325                 result = libops.scalar_binop(x, y, op)
#     326             except (
#
# ...

# %%
okt = Okt()
# 형태소 분석하는 함수
def
백터라이즈

# %%
디시젼 트리 클래스 파이어
피팅하기

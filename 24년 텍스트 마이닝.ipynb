# %% [markdown]
# 3월 5일 OT \
# 자연어 처리, 텍스트 마이닝 \
# 웹수집은 학술용은 괜찮을 줄 알았지만 피하고 간단하게 배울 것입니다. \
# 텍스트는 크기가 크지만 그래도 코랩으로 진행할 것입니다. \
# 3명 정도 특강 LG, SK, Naver 있을 예정

# %% [markdown]
# 3월 7일 \
# 1. data  -> **텍스트** -> 자연어 -> natural Languge \
# 비정형이다. 정형같지만 조각조각 나누어지지 않았다. \
#
# 2. **비정형** 보통 정형데이터를 -> 분석  회귀분석 같은 것 여러가지 기법만 알아 등 등 \
#   **정형화**하여야한다. (H는  / 밥을 / 먹다.) -> (1 1 1) 벡터로 정형화 효율적이다. \
#   LLM 라지 랭귀지 모델 언어 모형을 사용한다. ex) "나는" -> [...] 수치로 표현 \
#   정통 기법이나 최신 기법이나 비정형을 정형으로 바꿔라.
#
# 3. **토큰**(token) : 자연어를 쪼갠다. \
# "ㄴ ㅏ ㄴ ㅡ ㄴ" 의미 없어서 토큰이 아님 \
# "나는" 토큰이다. \
#  띄어쓰기로 나눌 수도 있고  I / eat / rice \
#  한국어는 조사 같은거로 "~를" \
#
# 4. 다량의 텍스트 -> 행을 다규멘트 열을 토큰으로 숫자로 채워준다. 이게 다규멘트 텀 메트릭스라고불린다. \
# 언어 모형에서는 행을 다규멘트 열을 토큰 비슷한데 참고만 하자.
#
# 5. **토픽** 모델링, **요약**(- 키워드, -군집 ...), 분류, 감성 ... 등 \
# 표에서 새로운 열을 추가한다 모델링한다? 이게 분류다? 문헌분류 \
# 감성 : "난 기분 정말 좋아요" 이건 "정말 좋아요"에서 2점 \
# 참고로 쓸모없는 것이 엄청 많은데 의미없거나 애매한 토큰? 이것들은 0점으로 하고 새롭게 정의한 특정한 기준에 따라 점수를 부여합니다.
#
# ------------------------------------------------
# HTS에서는 신문기사가 올라온다 이거에 따라 주가 이런게 바뀐다는데 정보에따라 뭐가 변한다. \
# 신문기사가 근데 낚시기사는 안된다. 진짜인지 아닌지 분류한다. \
# 라벨링? 모델링 한다? 새로운거 주면 이게 위처럼 분류 \
# 퀀트는 정보가 있고 텍스트로 표현 감성에따라 주가가 움직인다. \
# 이분들은 감성사전으로 분류한다. 토큰이 갖는 감성 점수를 준다. \
# 토픽 모델링이야 흔하다? \
#
# 강의안에서 정리를 해보자.

# %% [markdown]
# 3월 12일 \
# 수업전 참고로 코드로만 살아남기는 어렵다. \
# 데이터분석 + 코드 + 업무 자동화 + ... , zapier : 업무자동화 이런게 있음. \

# %% [markdown]
# 3월 14일 \
# 이론 수업

# %% [markdown]
# 3월 19일 \
# 실습 수업

# %% [markdown]
# 3월 21일 \
# 실습 수업

# %% [markdown]
# 3월 26일 \
# 졸업 시험으로 결석

# %% [markdown]
# 3월 28일 \
# 수업시작 \
# 웹 문서에서 텍스트를 가져온다, 파싱(문서를 이해하고 시키는 대로하는 것), 파싱할때 파서를 이용하는데 여러가지 인가보다. \
# 웹문서에서 파싱할때 언어가 HTML이고 마크업랭귀지이고 `<font> ~~ </fount>` \
# 동적인 기능을 넣을 때 javascript이다. \
# 1. 파이썬에는 리퀘스트라는 라이브러리를 이용하면 접속해서 웹문서를 가지고 올 수 있다. \
# 2. 셀레니어늄?? 이거는 관심있는 사람만 쓰기 시험이랑도 관련 없음.

# %% [markdown]
# 아래는 HTML기본 문법이라 중요하게 다루지는 않을 거임. \
# 참고로 xml은 내맘대로한 HTML??

# %% [markdown]
# `<html>` \
#   `<head>`\
#   `</head>`\
#   `<body></body>`\
# `</html>`
#
# 위와 같은 형태

# %% [markdown]
# Web Robots 에서 웹 크롤링??

# %% [markdown]
# 4월 2일 \
# txt를 다큐먼트 텀 메트릭으로 : [[ ],[ ],[ ],...[ ]] 정형데이터에 각각에 범주(taget)를 정한다. \
# (문헌 (자동) 분류) \
# 스팸 텍스트, 보이스피싱은 STT 금융에서 쓰임. \
# VOC 보이스 오프 커스터멀? 컨슈멀? 고객 분류? \
# AICC (ai고객센터) \
# 주어진 다큐멘트를 나눈다. \
# 다큐먼트의 텍스트와 타겟을 -> 다큐먼트 텀 메트릭스와 타켓 (텀과 타켓으로) \
# 라벨링은 최초는 무조건 사람이 타킷을 정해준다. DTM으로 정형데이터를 만든다. \
#
# 뉴스의 주가가 오르고 내리는데 어떤 텀들이 있을때 오르고 내리는지 분류와 예측하는 것. 뭐 증권사에서 리포트 뭐 직원들의 걷는 속도 밥 맛있는지 이상한거 많음. 남들이 많이 쓰지 않을때는 좋았는데 다 쓰니까 똑같아졌다. 그래서 뉴스 리포트 블로그 유튜브 등 새로운 알파를 찾으면 좋다. 이것을 대체 데이터라고 한다. \
# 리스트에 리스트는 아직 쓸수 없고 DTM과 머신러닝 분류를 쓰면 됩니다. \
#
# 실습하자.

# %% [markdown]
# 4월 4일 \
# 실습

# %% [markdown]
# 4월 9일 \
# AI HUB에서 고객센터에서 질문하고 받은 데이터? 실습

# %% [markdown]
# 4월 11일 \
# 이론 수업 \
# 나는/ 돈까스를/ 먹다    에서 먹다가 타겟 \
# 나는 -> 돈까스를 -> 먹다  토큰 하나하나 다음 토큰을 예측 이것이 생성 AI \
# 각각의 토큰을 표현하는 벡터? 벡터로 표현하는 것이 임베딩 \
# 확률값을 분류모형으로 \
# 프라이빗 언어모형을 만들어서 예를 들어 의료기록 의료생성 AI같은 것을 만듭니다. \
# 순방향 forwaed, 역방향으로 생성해주는 것을 GPT라고 합니다. \
# Generative Pre-trained Transformer  이다. Pre-trained은 이전에 학습 시키는 것 \
# mask? 이게 뭐냐면 나는 ' '  먹다에서 ' ' 이 부분이 mask이며 나는 과 먹다는 먹다 이다.  BERT? \
# p : 돈가스 과자 커피 \
# n : 시험 음쓰 담배  \
# 감정 스코어를 다 p는 +1, n:는 -1로 하든지 p를 +1,+2 ..n=-1, -6 다 다르게 하든지. \

# %% [markdown]
# 4월 16일 \
# 오늘 배운거 중요한 듯

# %% [markdown]
# 4월 18일 \
# 시험 정리

# %% [markdown]
# 4월 30일 \
# 수업

# %% [markdown]
# 5월 2일 \
# 수업 \
# 나중에 데이터셋 주고 기말 과제가 존재 분석하고 해석하는거 해보기

# %% [markdown]
# 5월 7일 \
# 이론 수업일 것이며 다음 수업 목요일은 예비군 간다고 말하기. \
#
# 유사도와 거리를 측정, 군집을 만들어서 해석 해석이 중요하다. \
# 근데 막 너무 많은 것을 해석하면 힘들어서 나온 것이 Topic이다. \
# 주제라고 간단하게 생각을 하면 됩니다. \
# 자, 여기서 Corpus가 있고 다큐멘트가 있습니다. \
# 만약에 다큐멘트 하나에 여러가지 토픽이 있다고 생각하면 하나의 토픽이 큰 확률이 가진다. \
# 각 토픽의 단어들이 발생할 확률이 있으므로 군집 분석과는 좀 다르다. \
# 내 생각인데 그러면 다큐메느 토픽 메트릭이라고 생각해도되고 발생할 확률 \
# 그리고 포픽 텀 메트릭이라고 있것 도 이렇게 생각 할 수 있을 것 같다. 발생할 확률 \
# (dtm -> sud -> ), (lsa, plsa가 있고), (lda) \
# 토픽에 대한 라벨링은 정성적이다. \
# 분석하는 사람의 주관이 필요하다. \
# 나중에 토픽의 갯수를 최적하는 방법도 있는데 뭔가 적정한 수준 많다고 좋은것은 아니다. \
# 30~40개가 적당하다고 하는데 이건 애매하다. \
# 여기서는 tfidf보다 tf을 사용하여 확률을 모델링하는 것을 선호합니다. \
# 불용어를 잘 발라내는 것은 중요합니다. \
# sklearn, gensim 이라는 라이브러리를 많이 사용합니다. \
# 근데 둘다 사용하는 방식은 많이 다릅니다. \
# 다른 gensim을 쓰는 이유는 c를 쓰기 때문에 빠르고 특화된 함수들이 있어서 2개 배우면 좋습니다. \
# **gensim** 많이 쓰니까. \
#
#
# 기말에 과제가 있다. (해서 내면 노력을 해서 하면 점수를 줍니다. 1. 시중에 돌아다니는 코퍼스 하나를 줄 것 입니다. ai허브라든지 정부나 국립 뭐시기 2. 결과 좋으면 일석이조지 공모전에 내든지.), 뉴스 수집해서 주식 주가가 올랐네 이런거 가능.

# %% [markdown]
# 5월 14일 \
# 수업

# %% [markdown]
# 5월 21일 \
# 실습 \
# 블랙 리스트, 화이트 리스트

# %% [markdown]
# 5월23일 \
#  수업

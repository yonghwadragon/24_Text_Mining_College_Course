# %% [markdown]
# 에타 안할거야

# %%
import requests
from bs4 import BeautifulSoup
from google.colab import userdata
import requests

# %%
# User-Agent 헤더 추가
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

res = requests.get('https://everytime.kr/login', headers=headers)
print(res)
print(res.text)  #수집된 내용
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#   <script>
# const gtmScript = document.createElement('script');
# gtmScript.toggleAttribute('async');
# gtmScript.src = 'https://www.googletagmanager.com/gtag/js?id=G-85ZNEFVRGL';
# gtmScript.onerror = function () {
#   window.gtag = undefined;
# }
# document.querySelector('head').append(gtmScript);
#
# window.dataLayer = window.dataLayer || [];
# function gtag() {
#   dataLayer.push(arguments);
# }
# gtag('js', new Date());
# gtag('config', 'G-85ZNEFVRGL', { 'send_page_view': false });
# </script>
#   <meta charset="utf-8">
#   <meta name="referrer" content="origin">
#   <meta name="viewport" content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=no">
#   <meta http-equiv="X-UA-Compatible" content="IE=edge">
#   <meta name="color-scheme" content="dark light">
#   <link rel="icon" href="/favicon.ico">
#   <link rel="icon" type="image/png" sizes="192x192" href="/favicon-192x192.png">
#   <link rel="apple-touch-icon" sizes="180x180" href="/favicon-180x180.png">
#   <meta property="og:type" content="website">
#   <meta property="og:site_name" content="에브리타임">
#   <title>로그인 - 에브리타임</title><meta data-vue-meta="ssr" name="robots" content="noindex"><link data-vue-meta="ssr" rel="preload" href="/css/11af1f2847a1d9348d10.css" as="style"><link data-vue-meta="ssr" rel="preload" href="/js/b094885e3b87fd7a569f.js" as="script"><link data-vue-meta="ssr" rel="stylesheet" href="/css/7592dd36ca61767c7f72.css"><script data-vue-meta="ssr" src="/js/b4cbe567400a1965626b.js" defer></script><script data-vue-meta="ssr" src="/js/9b35b27df69526155dc4.js" defer></script><script data-vue-meta="ssr" src="/js/5ad9ef3ddd4075506e52.js" defer></script><script data-vue-meta="ssr" src="/js/a260e2a782aa33cb623a.js" defer></script><script data-vue-meta="ssr" src="/js/545eb3dacd3c22cc84b5.js" defer></script><script data-vue-meta="ssr" src="/js/205ac1a9fca40fcef169.js" defer></script><script data-vue-meta="ssr" src="/js/04f4e346a9d4ba0155e7.js" defer></script>
# </head>
# <body>
#   <script src="https://www.google.com/recaptcha/enterprise.js?render=6LeQhDQpAAAAAKqtq7ZKTJ-mZEt8ohpVf_9V9Tom"></script>
#   <div id="app"></div>
#   <script id="__INITIAL_STATE__" type="application/json">{"accountServerUrl":"https://account.everytime.kr","appInfo":{"appName":"","appVersion":"","osName":"","osVersion":""},"pageName":"pages/login/index","pageTitle":"로그인","screenName":"어카운트 - 로그인","sentryDSN":"https://e0b06ba938d241bbb3e88a82651a7c44@o4504002973597696.ingest.sentry.io/4505464104222720","sentryENV":"production","appAuthScheme":null,"redirectUri":"https://everytime.kr","serviceagreementUrl":"https://everytime.kr/page/serviceagreement","privacyUrl":"https://everytime.kr/page/privacy","faqUrl":"https://everytime.kr/page/faq","copyrightUrl":"https://everytime.kr","recaptchaSiteKey":"6LeQhDQpAAAAAKqtq7ZKTJ-mZEt8ohpVf_9V9Tom"}</script>
# </body>
# </html>

# %%
soup = BeautifulSoup(res.text, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <script>
# const gtmScript = document.createElement('script');
# gtmScript.toggleAttribute('async');
# gtmScript.src = 'https://www.googletagmanager.com/gtag/js?id=G-85ZNEFVRGL';
# gtmScript.onerror = function () {
#   window.gtag = undefined;
# }
# document.querySelector('head').append(gtmScript);
#
# window.dataLayer = window.dataLayer || [];
# function gtag() {
#   dataLayer.push(arguments);
# }
# gtag('js', new Date());
# gtag('config', 'G-85ZNEFVRGL', { 'send_page_view': false });
# </script>
# <meta charset="utf-8"/>
# <meta content="origin" name="referrer"/>
# <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=no" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="dark light" name="color-scheme"/>
# <link href="/favicon.ico" rel="icon"/>
# <link href="/favicon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/favicon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <meta content="website" property="og:type"/>
# <meta content="에브리타임" property="og:site_name"/>
# <title>로그인 - 에브리타임</title><meta content="noindex" data-vue-meta="ssr" name="robots"/><link as="style" data-vue-meta="ssr" href="/css/11af1f2847a1d9348d10.css" rel="preload"/><link as="script" data-vue-meta="ssr" href="/js/b094885e3b87fd7a569f.js" rel="preload"/><link data-vue-meta="ssr" href="/css/7592dd36ca61767c7f72.css" rel="stylesheet"/><script data-vue-meta="ssr" defer="" src="/js/b4cbe567400a1965626b.js"></script><script data-vue-meta="ssr" defer="" src="/js/9b35b27df69526155dc4.js"></script><script data-vue-meta="ssr" defer="" src="/js/5ad9ef3ddd4075506e52.js"></script><script data-vue-meta="ssr" defer="" src="/js/a260e2a782aa33cb623a.js"></script><script data-vue-meta="ssr" defer="" src="/js/545eb3dacd3c22cc84b5.js"></script><script data-vue-meta="ssr" defer="" src="/js/205ac1a9fca40fcef169.js"></script><script data-vue-meta="ssr" defer="" src="/js/04f4e346a9d4ba0155e7.js"></script>
# </head>
# <body>
# <script src="https://www.google.com/recaptcha/enterprise.js?render=6LeQhDQpAAAAAKqtq7ZKTJ-mZEt8ohpVf_9V9Tom"></script>
# <div id="app"></div>
# <script id="__INITIAL_STATE__" type="application/json">{"accountServerUrl":"https://account.everytime.kr","appInfo":{"appName":"","appVersion":"","osName":"","osVersion":""},"pageName":"pages/login/index","pageTitle":"로그인","screenName":"어카운트 - 로그인","sentryDSN":"https://e0b06ba938d241bbb3e88a82651a7c44@o4504002973597696.ingest.sentry.io/4505464104222720","sentryENV":"production","appAuthScheme":null,"redirectUri":"https://everytime.kr","serviceagreementUrl":"https://everytime.kr/page/serviceagreement","privacyUrl":"https://everytime.kr/page/privacy","faqUrl":"https://everytime.kr/page/faq","copyrightUrl":"https://everytime.kr","recaptchaSiteKey":"6LeQhDQpAAAAAKqtq7ZKTJ-mZEt8ohpVf_9V9Tom"}</script>
# </body>
# </html>
